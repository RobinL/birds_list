# %%
import pandas as pd

# %%
df = pd.read_csv("the_british_list.csv")

# %%
df.head()
# Out:
#             common_name                                              link  \
# 0          Capercaillie  http://app.bto.org/birdfacts/results/bob3350.htm
# 1          Black Grouse  http://app.bto.org/birdfacts/results/bob3320.htm
# 2             Ptarmigan  http://app.bto.org/birdfacts/results/bob3300.htm
# 3            Red Grouse  http://app.bto.org/birdfacts/results/bob3292.htm
# 4  Red-legged Partridge  http://app.bto.org/birdfacts/results/bob3580.htm
#
#     scientific_name           status_in_uk                  pairs_text  \
# 0  Tetrao urogallus  Re-introduced Breeder         1000 - 10000 Adults
# 1    Lyrurus tetrix       Resident Breeder          1000 - 10000 Males
# 2      Lagopus muta       Resident Breeder          1000 - 10000 Pairs
# 3   Lagopus lagopus       Resident Breeder       100000 - 500000 Pairs
# 4    Alectoris rufa     Introduced Breeder  10000 - 100000 Territories
#
#   field_code_1 field_code_2  roughly_how_common
# ...

# %%
df = df.sort_values("roughly_how_common", ascending=False)

# %%
for num in [10,20,30,40]:
    df.head(num)[["common_name", "scientific_name"]].to_csv(f"quiz_lists/top_{num}.csv", index=False)

# %%
# Out:
#                    common_name  \
# 0                 Capercaillie
# 127              Ringed Plover
# 156                     Dunlin
# 157           Purple Sandpiper
# 318                   Barn Owl
# 381                 Willow Tit
# 326             Long-eared Owl
# 410      Yellow-browed Warbler
# 327            Short-eared Owl
# 330                 Kingfisher
# 336  Lesser Spotted Woodpecker
# 406               Wood Warbler
# 404            Cetti’s Warbler
# 345                     Merlin
# 346                      Hobby
# 348                  Peregrine
# 349       Ring-necked Parakeet
# 187                 Greenshank
# 386                   Woodlark
# 375                      Raven
# 379                Crested Tit
# 313                   Red Kite
# 225                Little Tern
# 324                 Little Owl
# 253         Red-throated Diver
# 129       Little Ringed Plover
# 256       Great Northern Diver
# 237                 Great Skua
# 282                  Cormorant
# ...
